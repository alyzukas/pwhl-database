# %% [markdown]
# # Team Project, Week 7: ETL Pipeline

# %% [markdown]
# ## Introduction
#
# ### Purpose:
# This week we will practice designing and implementing a simple ETL (Extract–Transform–Load) pipeline. The goal is to produce a clean, integrated dataset that reflects our project domain and supports more meaningful analysis.
#
# ### Technique:
# We will start with out cleaned team dataset and enrich it by ingesting at data from the PWHL HockeyTech API (via LeagueStat). Our original database was created referencing the same data that this API provides and therefore is a perfect source to continue building out this project. This API can be reached via the URL: https://lscluster.hockeytech.com/feed/index.php, along with specific parameters passed to access a vast amount of data. HockeyTech is a company that provides analytics, statistics, live data feeds, and streaming solutions to hockey organizations around the world from Junior to Professional level. The lscluster.hockeytech.com is part of LeagueStat, HockeyTech's statistics engine. This API fetches JSON data and we have selected this datasource to enhance our own data, and compare aggregated statistical summaries for players across every game to our individualized in-game view.
#
# ### Project Documentation
# Individual files for steps not performed in this summative notebook can be found the GitHub repository here: [pwhl-database](https://github.com/alyzukas/pwhl-database/tree/main)

# %%
# Import libraries
import sqlite3
import pandas as pd
import requests
from pprint import pprint
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Part 1 – Extract

# %% [markdown]
# ### Load your cleaned dataset from Week 6

# %%
# Connect to `week6_pwhl` SQLite database 
db_path = "/Users/alyssa.zukas/cpsc5071/week6_pwhl.db"  # -- INSERT YOUR PATH HERE  
conn = sqlite3.connect(db_path)

# QUERY 1 - SHOT-LEVEL DATASET
# Paste the query text 
query_1 = """
SELECT t.name as shooting_team
,gm.game_date
,gm.duration
-- shooter details
,shooter.name as shooter_name
,shooter.player_key
,tn.position
,shooter.shoots as shoots_handed
,shooter.hometown
,shooter.birthdate
,tn.jersey_number
-- shot details
,s.shot_key 
,s.shot_type
,s.shot_time
,s.shot_quality
-- goalie details
,goalie.name as goalie_name
,s.is_goal
--blocker and assists
,blocker.name AS blocker_name
,pa.name AS assist1_name
,pa2.name as assist2_name
--goal details
,gl.is_power_play as is_power_play_goal
,gl.is_short_handed as is_short_handed_goal
,gl.is_empty_net as is_empty_net_goal
,gl.is_penalty_shot as is_penalty_shot_goal
,gl.is_insurance_goal
,gl.is_game_winning_goal
,s.x_location
,s.y_location
FROM shot s
INNER JOIN game gm 
	on s.game_key=gm.game_key
INNER JOIN player shooter 
	on s.shooter_key=shooter.player_key
INNER JOIN player goalie
	on s.goalie_key=goalie.player_key
LEFT JOIN player blocker
	on s.blocker_key=blocker.player_key
INNER JOIN tenure tn
    ON shooter.player_key = tn.player_key
   AND gm.season_key = tn.season_key
INNER JOIN team t
    ON tn.team_key = t.team_key
LEFT JOIN goal gl 
	ON s.game_key=gl.game_key
    AND s.shot_key=gl.shot_key
LEFT JOIN assist a 
	ON gl.game_key=a.game_key
	AND gl.goal_key=a.goal_key
    AND a.assist_number = 1
LEFT JOIN assist a2
	ON gl.game_key=a2.game_key
	AND gl.goal_key=a2.goal_key
    AND a2.assist_number = 2
LEFT JOIN player pa
	ON a.player_key=pa.player_key
LEFT JOIN player pa2
    ON a2.player_key=pa2.player_key
ORDER BY s.shot_key;
"""

# %%
# Load the query_1 into Pandas
df = pd.read_sql(query_1, conn)

# Collect the goal fields which need NAs filled with 0
goal_flag_cols = [
    "is_power_play_goal",
    "is_short_handed_goal",
    "is_empty_net_goal",
    "is_penalty_shot_goal",
    "is_insurance_goal",
    "is_game_winning_goal"
]

# Collect the name fields which need NAs filled with "None"
conditional_name_cols = [
    "blocker_name", 
    "assist1_name", 
    "assist2_name"
]

# Fill Categorical missing values with "None"
df[conditional_name_cols] = df[conditional_name_cols].fillna("None")

# Fill Goal Flags with 0 
df[goal_flag_cols] = df[goal_flag_cols].fillna(0).astype(int)

# Collect all object fields which need explicit conversion to string
to_string_cols = [
    "shooting_team",
    "shooter_name",  
    "shoots_handed",
    "position",
    "hometown",
    "shot_type",
    "shot_quality",
    "goalie_name",
    "blocker_name",
    "assist1_name",
    "assist2_name"
]

# Collect all object fields which need explicit conversion to datetime
to_datetime_cols = [
    "duration",
    "game_date",
    "birthdate",
    "shot_time"
]

# Collect all object fields which need explicit conversion to integer
to_int_cols = [
    "is_power_play_goal",
    "is_short_handed_goal",
    "is_empty_net_goal",
    "is_penalty_shot_goal",
    "is_insurance_goal",
    "is_game_winning_goal"
]

#Cast as string
for i in to_string_cols:
    df[i] = df[i].astype("string")

#Cast as datetime
for i in to_datetime_cols:
    df[i] = pd.to_datetime(df[i])

#cast as integer
for i in to_int_cols:
    df[i] = df[i].astype("int64")

#split town and state/territory from 'hometown'
df[['hometown','home_state_or_territory']] = df.hometown.str.split(",", n=1, expand=True)

#create calculated field, 'duration_hours'
df['duration_hours'] = df['duration'].dt.hour + df['duration'].dt.minute / 60

# %%
df.head()
# Out:
#       shooting_team  game_date            duration     shooter_name  \
# 0  Toronto Sceptres 2026-01-20 2000-01-01 02:31:00  Blayre Turnbull
# 1   Seattle Torrent 2026-01-18 2000-01-01 02:45:00   Alex Carpenter
# 2      Boston Fleet 2026-01-18 2000-01-01 02:45:00     Megan Keller
# 3      Boston Fleet 2026-01-18 2000-01-01 02:45:00     Megan Keller
# 4      Boston Fleet 2026-01-18 2000-01-01 02:45:00       Haley Winn
#
#    player_key position shoots_handed       hometown  birthdate  jersey_number  \
# 0          76        F             R     Stellarton 1993-07-15             19
# 1          34        G             L  North Reading 1994-04-13             31
# 2          12        C             L     Farmington 1996-05-01             77
# 3          12        C             L     Farmington 1996-05-01             77
# 4         246        F             R      Rochester 2003-07-14             88
#
#    shot_key shot_type           shot_time         shot_quality  \
# 0         4     Wrist 2000-01-01 00:01:18         Quality goal
# 1        16   Default 2000-01-01 00:06:20  Non quality blocked
# 2        36      Slap 2000-01-01 00:12:28     Non quality goal
# 3        41      Slap 2000-01-01 00:13:50  Non quality blocked
# 4        43   Default 2000-01-01 00:14:00  Non quality blocked
#
#          goalie_name  is_goal    blocker_name   assist1_name     assist2_name  \
# 0  Corinne Schroeder        1            None  Claire Dalton    Kali Flanagan
# 1      Aerin Frankel        0   Jill Saulnier    Daryl Watts  Savannah Harmon
# 2  Corinne Schroeder        1            None   Abby Newhook     Alina Müller
# 3  Corinne Schroeder        0  Mariah Keopple           None             None
# 4  Corinne Schroeder        0    Lexie Adzija           None             None
#
#    is_power_play_goal  is_short_handed_goal  is_empty_net_goal  \
# 0                   0                     0                  0
# 1                   0                     0                  0
# 2                   1                     0                  0
# 3                   0                     0                  0
# 4                   0                     0                  0
#
#    is_penalty_shot_goal  is_insurance_goal  is_game_winning_goal  x_location  \
# 0                     0                  0                     0         513
# 1                     0                  0                     0         175
# 2                     0                  0                     0         423
# 3                     0                  0                     0         434
# 4                     0                  0                     0         389
#
#    y_location home_state_or_territory  duration_hours
# 0         196                      NS        2.516667
# 1         143                      MA        2.750000
# 2         203                      MI        2.750000
# 3         217                      MI        2.750000
# 4         173                      NY        2.750000

# %% [markdown]
# ### Ingest at least one of the following external data sources

# %%
#url for API we will be using
url = "https://lscluster.hockeytech.com/feed/index.php"

#Dictionary of the parameters which the endpoint accepts and the values we will be providing
params = {
    "feed": "statviewfeed",
    "view": "players", 
    "season": 8,
    "team": "all",
    "position": "skaters", 
    "rookies": 0,
    "statsType": "standard",
    "league_id": 1,
    "limit": 500,
    "sort": "points",
    "lang": "en",
    "key": "446521baf8c38984",
    "client_code": "pwhl"
}

response = requests.get(url, params=params)

if response.status_code == 200:
    cleaned_text = response.text.strip()[1:-1]  # note that this data came through as JSONP, so we strip the 1st and last characters: ()
    api_data = json.loads(cleaned_text)
    print("we've got data!")
else:
    print("penalty assessed:", response.status_code)
# Out:
# we've got data!

# %%
# analyze the structure of the data
pprint(api_data)
# Out:
# [{'sections': [{'data': [{'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '20',
#                                             'seoName': 'Kendall Coyne '
#                                                        'Schofield'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '1',
#                                   'faceoff_pct': '100.0',
#                                   'faceoff_wins': '1',
#                                   'games_played': '15',
#                                   'goals': '10',
#                                   'hits': '5',
#                                   'hits_per_game_avg': '0.33',
#                                   'ice_time_minutes_seconds': '250:40',
#                                   'ice_time_per_game_avg': '16:42',
#                                   'name': 'Kendall Coyne Schofield',
#                                   'penalty_minutes': '0',
#                                   'penalty_minutes_per_game': '0.00',
#                                   'player_id': '20',
#                                   'plus_minus': '13',
#                                   'points': '16',
#                                   'points_per_game': '1.07',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '0',
#                                   'rank': 1,
#                                   'rookie': '0',
#                                   'shooting_percentage': '20.8',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '48',
#                                   'shots_blocked_by_player': '5',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '189',
#                                             'seoName': 'Britta Curl-Salemme'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '9',
#                                   'faceoff_attempts': '37',
#                                   'faceoff_pct': '51.4',
#                                   'faceoff_wins': '19',
#                                   'games_played': '15',
#                                   'goals': '7',
#                                   'hits': '17',
#                                   'hits_per_game_avg': '1.13',
#                                   'ice_time_minutes_seconds': '266:50',
#                                   'ice_time_per_game_avg': '17:47',
#                                   'name': 'Britta Curl-Salemme',
#                                   'penalty_minutes': '8',
#                                   'penalty_minutes_per_game': '0.53',
#                                   'player_id': '189',
#                                   'plus_minus': '12',
#                                   'points': '16',
#                                   'points_per_game': '1.07',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '0',
#                                   'rank': 2,
#                                   'rookie': '0',
#                                   'shooting_percentage': '25.0',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '28',
#                                   'shots_blocked_by_player': '17',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '21',
#                                             'seoName': 'Taylor Heise'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '13',
#                                   'faceoff_attempts': '220',
#                                   'faceoff_pct': '48.2',
#                                   'faceoff_wins': '106',
#                                   'games_played': '15',
#                                   'goals': '3',
#                                   'hits': '13',
#                                   'hits_per_game_avg': '0.87',
#                                   'ice_time_minutes_seconds': '255:51',
#                                   'ice_time_per_game_avg': '17:03',
#                                   'name': 'Taylor Heise',
#                                   'penalty_minutes': '6',
#                                   'penalty_minutes_per_game': '0.40',
#                                   'player_id': '21',
#                                   'plus_minus': '11',
#                                   'points': '16',
#                                   'points_per_game': '1.07',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '0',
#                                   'rank': 3,
#                                   'rookie': '0',
#                                   'shooting_percentage': '7.9',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '38',
#                                   'shots_blocked_by_player': '3',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '23',
#                                             'seoName': 'Kelly Pannek'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '271',
#                                   'faceoff_pct': '57.9',
#                                   'faceoff_wins': '157',
#                                   'games_played': '15',
#                                   'goals': '8',
#                                   'hits': '2',
#                                   'hits_per_game_avg': '0.13',
#                                   'ice_time_minutes_seconds': '256:52',
#                                   'ice_time_per_game_avg': '17:07',
#                                   'name': 'Kelly Pannek',
#                                   'penalty_minutes': '2',
#                                   'penalty_minutes_per_game': '0.13',
#                                   'player_id': '23',
#                                   'plus_minus': '10',
#                                   'points': '15',
#                                   'points_per_game': '1.00',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '3',
#                                   'rank': 4,
#                                   'rookie': '0',
#                                   'shooting_percentage': '24.2',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '33',
#                                   'shots_blocked_by_player': '15',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '58',
#                                             'seoName': 'Brianne Jenner'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '5'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '280',
#                                   'faceoff_pct': '56.8',
#                                   'faceoff_wins': '159',
#                                   'games_played': '16',
#                                   'goals': '8',
#                                   'hits': '12',
#                                   'hits_per_game_avg': '0.75',
#                                   'ice_time_minutes_seconds': '305:29',
#                                   'ice_time_per_game_avg': '19:05',
#                                   'name': 'Brianne Jenner',
#                                   'penalty_minutes': '6',
#                                   'penalty_minutes_per_game': '0.38',
#                                   'player_id': '58',
#                                   'plus_minus': '2',
#                                   'points': '15',
#                                   'points_per_game': '0.94',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '3',
#                                   'rank': 5,
#                                   'rookie': '0',
#                                   'shooting_percentage': '17.0',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '1',
#                                   'shots': '47',
#                                   'shots_blocked_by_player': '5',
#                                   'team_code': 'OTT'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '72',
#                                             'seoName': 'Rebecca Leslie'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '5'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '7',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '16',
#                                   'goals': '8',
#                                   'hits': '3',
#                                   'hits_per_game_avg': '0.19',
#                                   'ice_time_minutes_seconds': '294:36',
#                                   'ice_time_per_game_avg': '18:24',
#                                   'name': 'Rebecca Leslie',
#                                   'penalty_minutes': '0',
#                                   'penalty_minutes_per_game': '0.00',
#                                   'player_id': '72',
#                                   'plus_minus': '3',
#                                   'points': '14',
#                                   'points_per_game': '0.88',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '2',
#                                   'rank': 6,
#                                   'rookie': '0',
#                                   'shooting_percentage': '18.6',
#                                   'short_handed_assists': '1',
#                                   'short_handed_goals': '0',
#                                   'shots': '43',
#                                   'shots_blocked_by_player': '2',
#                                   'team_code': 'OTT'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '31',
#                                             'seoName': 'Marie-Philip Poulin'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '3'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '274',
#                                   'faceoff_pct': '63.9',
#                                   'faceoff_wins': '175',
#                                   'games_played': '15',
#                                   'goals': '7',
#                                   'hits': '19',
#                                   'hits_per_game_avg': '1.27',
#                                   'ice_time_minutes_seconds': '300:57',
#                                   'ice_time_per_game_avg': '20:03',
#                                   'name': 'Marie-Philip Poulin',
#                                   'penalty_minutes': '18',
#                                   'penalty_minutes_per_game': '1.20',
#                                   'player_id': '31',
#                                   'plus_minus': '3',
#                                   'points': '14',
#                                   'points_per_game': '0.93',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '2',
#                                   'rank': 7,
#                                   'rookie': '0',
#                                   'shooting_percentage': '14.9',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '47',
#                                   'shots_blocked_by_player': '11',
#                                   'team_code': 'MTL'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '210',
#                                             'seoName': 'Julia Gosling'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '8'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '5',
#                                   'faceoff_pct': '20.0',
#                                   'faceoff_wins': '1',
#                                   'games_played': '15',
#                                   'goals': '6',
#                                   'hits': '7',
#                                   'hits_per_game_avg': '0.47',
#                                   'ice_time_minutes_seconds': '274:00',
#                                   'ice_time_per_game_avg': '18:16',
#                                   'name': 'Julia Gosling',
#                                   'penalty_minutes': '8',
#                                   'penalty_minutes_per_game': '0.53',
#                                   'player_id': '210',
#                                   'plus_minus': '0',
#                                   'points': '13',
#                                   'points_per_game': '0.87',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '1',
#                                   'rank': 8,
#                                   'rookie': '0',
#                                   'shooting_percentage': '10.7',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '56',
#                                   'shots_blocked_by_player': '7',
#                                   'team_code': 'SEA'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '245',
#                                             'seoName': 'Kristýna Kaltounková'},
#                                    'rookie': {'rookie': '1'},
#                                    'team_code': {'teamLink': '4'}},
#                           'row': {'active': '1',
#                                   'assists': '1',
#                                   'faceoff_attempts': '31',
#                                   'faceoff_pct': '45.2',
#                                   'faceoff_wins': '14',
#                                   'games_played': '17',
#                                   'goals': '11',
#                                   'hits': '26',
#                                   'hits_per_game_avg': '1.53',
#                                   'ice_time_minutes_seconds': '337:00',
#                                   'ice_time_per_game_avg': '19:49',
#                                   'name': 'Kristýna Kaltounková',
#                                   'penalty_minutes': '33',
#                                   'penalty_minutes_per_game': '1.94',
#                                   'player_id': '245',
#                                   'plus_minus': '2',
#                                   'points': '12',
#                                   'points_per_game': '0.71',
#                                   'position': 'F',
#                                   'power_play_assists': '0',
#                                   'power_play_goals': '2',
#                                   'rank': 9,
#                                   'rookie': '1',
#                                   'shooting_percentage': '15.5',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '71',
#                                   'shots_blocked_by_player': '9',
#                                   'team_code': 'NY'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '63',
#                                             'seoName': 'Daryl Watts'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '6'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '5',
#                                   'faceoff_pct': '20.0',
#                                   'faceoff_wins': '1',
#                                   'games_played': '16',
#                                   'goals': '6',
#                                   'hits': '2',
#                                   'hits_per_game_avg': '0.13',
#                                   'ice_time_minutes_seconds': '280:47',
#                                   'ice_time_per_game_avg': '17:32',
#                                   'name': 'Daryl Watts',
#                                   'penalty_minutes': '0',
#                                   'penalty_minutes_per_game': '0.00',
#                                   'player_id': '63',
#                                   'plus_minus': '-1',
#                                   'points': '12',
#                                   'points_per_game': '0.75',
#                                   'position': 'F',
#                                   'power_play_assists': '0',
#                                   'power_play_goals': '1',
#                                   'rank': 10,
#                                   'rookie': '0',
#                                   'shooting_percentage': '10.3',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '58',
#                                   'shots_blocked_by_player': '8',
#                                   'team_code': 'TOR'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '42',
#                                             'seoName': 'Abby Roque'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '3'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '140',
#                                   'faceoff_pct': '54.3',
#                                   'faceoff_wins': '76',
#                                   'games_played': '15',
#                                   'goals': '5',
#                                   'hits': '15',
#                                   'hits_per_game_avg': '1.00',
#                                   'ice_time_minutes_seconds': '301:40',
#                                   'ice_time_per_game_avg': '20:06',
#                                   'name': 'Abby Roque',
#                                   'penalty_minutes': '27',
#                                   'penalty_minutes_per_game': '1.80',
#                                   'player_id': '42',
#                                   'plus_minus': '2',
#                                   'points': '12',
#                                   'points_per_game': '0.80',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '0',
#                                   'rank': 11,
#                                   'rookie': '0',
#                                   'shooting_percentage': '14.7',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '34',
#                                   'shots_blocked_by_player': '5',
#                                   'team_code': 'MTL'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '280',
#                                             'seoName': "Casey O'Brien"},
#                                    'rookie': {'rookie': '1'},
#                                    'team_code': {'teamLink': '4'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '299',
#                                   'faceoff_pct': '53.8',
#                                   'faceoff_wins': '161',
#                                   'games_played': '17',
#                                   'goals': '5',
#                                   'hits': '3',
#                                   'hits_per_game_avg': '0.18',
#                                   'ice_time_minutes_seconds': '342:42',
#                                   'ice_time_per_game_avg': '20:09',
#                                   'name': "Casey O'Brien",
#                                   'penalty_minutes': '0',
#                                   'penalty_minutes_per_game': '0.00',
#                                   'player_id': '280',
#                                   'plus_minus': '-4',
#                                   'points': '12',
#                                   'points_per_game': '0.71',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '3',
#                                   'rank': 12,
#                                   'rookie': '1',
#                                   'shooting_percentage': '13.9',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '1',
#                                   'shots': '36',
#                                   'shots_blocked_by_player': '5',
#                                   'team_code': 'NY'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '12',
#                                             'seoName': 'Megan Keller'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '1'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '0',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '14',
#                                   'goals': '5',
#                                   'hits': '22',
#                                   'hits_per_game_avg': '1.57',
#                                   'ice_time_minutes_seconds': '375:45',
#                                   'ice_time_per_game_avg': '26:50',
#                                   'name': 'Megan Keller',
#                                   'penalty_minutes': '0',
#                                   'penalty_minutes_per_game': '0.00',
#                                   'player_id': '12',
#                                   'plus_minus': '-1',
#                                   'points': '11',
#                                   'points_per_game': '0.79',
#                                   'position': 'LD',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '4',
#                                   'rank': 13,
#                                   'rookie': '0',
#                                   'shooting_percentage': '15.2',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '33',
#                                   'shots_blocked_by_player': '9',
#                                   'team_code': 'BOS'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '36',
#                                             'seoName': 'Jessie Eldridge'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '8'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '8',
#                                   'faceoff_pct': '37.5',
#                                   'faceoff_wins': '3',
#                                   'games_played': '15',
#                                   'goals': '5',
#                                   'hits': '6',
#                                   'hits_per_game_avg': '0.40',
#                                   'ice_time_minutes_seconds': '255:36',
#                                   'ice_time_per_game_avg': '17:02',
#                                   'name': 'Jessie Eldridge',
#                                   'penalty_minutes': '4',
#                                   'penalty_minutes_per_game': '0.27',
#                                   'player_id': '36',
#                                   'plus_minus': '-3',
#                                   'points': '11',
#                                   'points_per_game': '0.73',
#                                   'position': 'F',
#                                   'power_play_assists': '1',
#                                   'power_play_goals': '0',
#                                   'rank': 14,
#                                   'rookie': '0',
#                                   'shooting_percentage': '17.2',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '29',
#                                   'shots_blocked_by_player': '4',
#                                   'team_code': 'SEA'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '205',
#                                             'seoName': 'Sarah Fillier'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '4'}},
#                           'row': {'active': '1',
#                                   'assists': '10',
#                                   'faceoff_attempts': '143',
#                                   'faceoff_pct': '44.1',
#                                   'faceoff_wins': '63',
#                                   'games_played': '16',
#                                   'goals': '1',
#                                   'hits': '23',
#                                   'hits_per_game_avg': '1.44',
#                                   'ice_time_minutes_seconds': '323:11',
#                                   'ice_time_per_game_avg': '20:11',
#                                   'name': 'Sarah Fillier',
#                                   'penalty_minutes': '2',
#                                   'penalty_minutes_per_game': '0.13',
#                                   'player_id': '205',
#                                   'plus_minus': '-2',
#                                   'points': '11',
#                                   'points_per_game': '0.69',
#                                   'position': 'F',
#                                   'power_play_assists': '5',
#                                   'power_play_goals': '0',
#                                   'rank': 15,
#                                   'rookie': '0',
#                                   'shooting_percentage': '1.7',
#                                   'short_handed_assists': '1',
#                                   'short_handed_goals': '0',
#                                   'shots': '58',
#                                   'shots_blocked_by_player': '8',
#                                   'team_code': 'NY'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '34',
#                                             'seoName': 'Alex Carpenter'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '8'}},
#                           'row': {'active': '1',
#                                   'assists': '5',
#                                   'faceoff_attempts': '354',
#                                   'faceoff_pct': '60.2',
#                                   'faceoff_wins': '213',
#                                   'games_played': '15',
#                                   'goals': '5',
#                                   'hits': '1',
#                                   'hits_per_game_avg': '0.07',
#                                   'ice_time_minutes_seconds': '305:48',
#                                   'ice_time_per_game_avg': '20:23',
#                                   'name': 'Alex Carpenter',
#                                   'penalty_minutes': '2',
#                                   'penalty_minutes_per_game': '0.13',
#                                   'player_id': '34',
#                                   'plus_minus': '-6',
#                                   'points': '10',
#                                   'points_per_game': '0.67',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '2',
#                                   'rank': 16,
#                                   'rookie': '0',
#                                   'shooting_percentage': '11.1',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '45',
#                                   'shots_blocked_by_player': '8',
#                                   'team_code': 'SEA'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '13',
#                                             'seoName': 'Hilary Knight'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '8'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '5',
#                                   'faceoff_pct': '60.0',
#                                   'faceoff_wins': '3',
#                                   'games_played': '14',
#                                   'goals': '3',
#                                   'hits': '12',
#                                   'hits_per_game_avg': '0.86',
#                                   'ice_time_minutes_seconds': '285:06',
#                                   'ice_time_per_game_avg': '20:21',
#                                   'name': 'Hilary Knight',
#                                   'penalty_minutes': '4',
#                                   'penalty_minutes_per_game': '0.29',
#                                   'player_id': '13',
#                                   'plus_minus': '-2',
#                                   'points': '10',
#                                   'points_per_game': '0.71',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '3',
#                                   'rank': 17,
#                                   'rookie': '0',
#                                   'shooting_percentage': '7.0',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '43',
#                                   'shots_blocked_by_player': '6',
#                                   'team_code': 'SEA'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '188',
#                                             'seoName': 'Mae Batherson'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '8',
#                                   'faceoff_attempts': '3',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '15',
#                                   'goals': '2',
#                                   'hits': '3',
#                                   'hits_per_game_avg': '0.20',
#                                   'ice_time_minutes_seconds': '296:03',
#                                   'ice_time_per_game_avg': '19:44',
#                                   'name': 'Mae Batherson',
#                                   'penalty_minutes': '2',
#                                   'penalty_minutes_per_game': '0.13',
#                                   'player_id': '188',
#                                   'plus_minus': '7',
#                                   'points': '10',
#                                   'points_per_game': '0.67',
#                                   'position': 'D',
#                                   'power_play_assists': '4',
#                                   'power_play_goals': '1',
#                                   'rank': 18,
#                                   'rookie': '0',
#                                   'shooting_percentage': '8.7',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '23',
#                                   'shots_blocked_by_player': '9',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '32',
#                                             'seoName': 'Laura Stacey'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '3'}},
#                           'row': {'active': '1',
#                                   'assists': '8',
#                                   'faceoff_attempts': '1',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '16',
#                                   'goals': '2',
#                                   'hits': '9',
#                                   'hits_per_game_avg': '0.56',
#                                   'ice_time_minutes_seconds': '313:17',
#                                   'ice_time_per_game_avg': '19:34',
#                                   'name': 'Laura Stacey',
#                                   'penalty_minutes': '10',
#                                   'penalty_minutes_per_game': '0.63',
#                                   'player_id': '32',
#                                   'plus_minus': '5',
#                                   'points': '10',
#                                   'points_per_game': '0.63',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '1',
#                                   'rank': 19,
#                                   'rookie': '0',
#                                   'shooting_percentage': '2.9',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '70',
#                                   'shots_blocked_by_player': '7',
#                                   'team_code': 'MTL'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '25',
#                                             'seoName': 'Grace Zumwinkle'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '2'}},
#                           'row': {'active': '1',
#                                   'assists': '3',
#                                   'faceoff_attempts': '6',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '15',
#                                   'goals': '6',
#                                   'hits': '2',
#                                   'hits_per_game_avg': '0.13',
#                                   'ice_time_minutes_seconds': '248:11',
#                                   'ice_time_per_game_avg': '16:32',
#                                   'name': 'Grace Zumwinkle',
#                                   'penalty_minutes': '4',
#                                   'penalty_minutes_per_game': '0.27',
#                                   'player_id': '25',
#                                   'plus_minus': '-3',
#                                   'points': '9',
#                                   'points_per_game': '0.60',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '2',
#                                   'rank': 20,
#                                   'rookie': '0',
#                                   'shooting_percentage': '14.3',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '42',
#                                   'shots_blocked_by_player': '10',
#                                   'team_code': 'MIN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '181',
#                                             'seoName': 'Hannah Bilka'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '8'}},
#                           'row': {'active': '1',
#                                   'assists': '5',
#                                   'faceoff_attempts': '2',
#                                   'faceoff_pct': '50.0',
#                                   'faceoff_wins': '1',
#                                   'games_played': '14',
#                                   'goals': '4',
#                                   'hits': '8',
#                                   'hits_per_game_avg': '0.57',
#                                   'ice_time_minutes_seconds': '251:12',
#                                   'ice_time_per_game_avg': '17:56',
#                                   'name': 'Hannah Bilka',
#                                   'penalty_minutes': '2',
#                                   'penalty_minutes_per_game': '0.14',
#                                   'player_id': '181',
#                                   'plus_minus': '-6',
#                                   'points': '9',
#                                   'points_per_game': '0.64',
#                                   'position': 'F',
#                                   'power_play_assists': '5',
#                                   'power_play_goals': '0',
#                                   'rank': 21,
#                                   'rookie': '0',
#                                   'shooting_percentage': '10.5',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '38',
#                                   'shots_blocked_by_player': '7',
#                                   'team_code': 'SEA'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '169',
#                                             'seoName': 'Claire Thompson'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '9'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '0',
#                                   'faceoff_pct': '0.0',
#                                   'faceoff_wins': '0',
#                                   'games_played': '15',
#                                   'goals': '3',
#                                   'hits': '7',
#                                   'hits_per_game_avg': '0.47',
#                                   'ice_time_minutes_seconds': '325:51',
#                                   'ice_time_per_game_avg': '21:43',
#                                   'name': 'Claire Thompson',
#                                   'penalty_minutes': '6',
#                                   'penalty_minutes_per_game': '0.40',
#                                   'player_id': '169',
#                                   'plus_minus': '1',
#                                   'points': '9',
#                                   'points_per_game': '0.60',
#                                   'position': 'D',
#                                   'power_play_assists': '0',
#                                   'power_play_goals': '1',
#                                   'rank': 22,
#                                   'rookie': '0',
#                                   'shooting_percentage': '10.7',
#                                   'short_handed_assists': '1',
#                                   'short_handed_goals': '0',
#                                   'shots': '28',
#                                   'shots_blocked_by_player': '18',
#                                   'team_code': 'VAN'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '73',
#                                             'seoName': 'Emma Maltais'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '6'}},
#                           'row': {'active': '1',
#                                   'assists': '6',
#                                   'faceoff_attempts': '218',
#                                   'faceoff_pct': '53.2',
#                                   'faceoff_wins': '116',
#                                   'games_played': '17',
#                                   'goals': '3',
#                                   'hits': '29',
#                                   'hits_per_game_avg': '1.71',
#                                   'ice_time_minutes_seconds': '322:57',
#                                   'ice_time_per_game_avg': '18:59',
#                                   'name': 'Emma Maltais',
#                                   'penalty_minutes': '12',
#                                   'penalty_minutes_per_game': '0.71',
#                                   'player_id': '73',
#                                   'plus_minus': '-1',
#                                   'points': '9',
#                                   'points_per_game': '0.53',
#                                   'position': 'F',
#                                   'power_play_assists': '2',
#                                   'power_play_goals': '0',
#                                   'rank': 23,
#                                   'rookie': '0',
#                                   'shooting_percentage': '10.0',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '30',
#                                   'shots_blocked_by_player': '14',
#                                   'team_code': 'TOR'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '57',
#                                             'seoName': 'Gabbie Hughes'},
#                                    'rookie': {'rookie': '0'},
#                                    'team_code': {'teamLink': '5'}},
#                           'row': {'active': '1',
#                                   'assists': '7',
#                                   'faceoff_attempts': '183',
#                                   'faceoff_pct': '45.9',
#                                   'faceoff_wins': '84',
#                                   'games_played': '14',
#                                   'goals': '2',
#                                   'hits': '12',
#                                   'hits_per_game_avg': '0.86',
#                                   'ice_time_minutes_seconds': '216:42',
#                                   'ice_time_per_game_avg': '15:28',
#                                   'name': 'Gabbie Hughes',
#                                   'penalty_minutes': '8',
#                                   'penalty_minutes_per_game': '0.57',
#                                   'player_id': '57',
#                                   'plus_minus': '-6',
#                                   'points': '9',
#                                   'points_per_game': '0.64',
#                                   'position': 'F',
#                                   'power_play_assists': '3',
#                                   'power_play_goals': '1',
#                                   'rank': 24,
#                                   'rookie': '0',
#                                   'shooting_percentage': '9.5',
#                                   'short_handed_assists': '0',
#                                   'short_handed_goals': '0',
#                                   'shots': '21',
#                                   'shots_blocked_by_player': '5',
#                                   'team_code': 'OTT'}},
#                          {'prop': {'active': {'active': '1'},
#                                    'name': {'playerLink': '15',
#                                             'seoName': 'Alina Müller'},
# ...
#                                                                         'highlight': False,
#                                                                         'key': 'ice_time_minutes_seconds',
#                                                                         'label': 'TOI',
#                                                                         'sortKey': 'ice_time_minutes_seconds',
#                                                                         'sortable': True,
#                                                                         'title': 'TOI'}},
#                             'ice_time_per_game_avg': {'properties': {'align': 'left',
#                                                                      'class': '',
#                                                                      'hidden': False,
#                                                                      'highlight': False,
#                                                                      'key': 'ice_time_per_game_avg',
#                                                                      'label': 'TOI/GP',
#                                                                      'sortKey': 'ice_time_per_game_avg',
#                                                                      'sortable': True,
#                                                                      'title': 'Time '
#                                                                               'on '
#                                                                               'Ice '
#                                                                               'per '
#                                                                               'Game '}},
#                             'name': {'properties': {'align': 'left',
#                                                     'class': '',
#                                                     'hidden': False,
#                                                     'highlight': False,
#                                                     'key': 'name',
#                                                     'label': 'Name',
#                                                     'sortKey': 'name',
#                                                     'sortable': True,
#                                                     'title': 'Name'}},
#                             'penalty_minutes': {'properties': {'align': 'center',
#                                                                'class': '',
#                                                                'hidden': False,
#                                                                'highlight': False,
#                                                                'key': 'penalty_minutes',
#                                                                'label': 'PIM',
#                                                                'sortKey': 'pim',
#                                                                'sortable': True,
#                                                                'title': 'Penalty '
#                                                                         'Minutes'}},
#                             'penalty_minutes_per_game': {'properties': {'align': 'center',
#                                                                         'class': '',
#                                                                         'hidden': False,
#                                                                         'highlight': False,
#                                                                         'key': 'penalty_minutes_per_game',
#                                                                         'label': 'PIMPG',
#                                                                         'sortKey': 'pimpg',
#                                                                         'sortable': True,
#                                                                         'title': 'Penalty '
#                                                                                  'Minutes '
#                                                                                  'per '
#                                                                                  'Game'}},
#                             'player_id': {'properties': {'align': 'center',
#                                                          'class': '',
#                                                          'hidden': True,
#                                                          'highlight': False,
#                                                          'key': 'player_id',
#                                                          'label': '',
#                                                          'sortKey': '',
#                                                          'sortable': True,
#                                                          'title': ''}},
#                             'plus_minus': {'properties': {'align': 'center',
#                                                           'class': '',
#                                                           'hidden': False,
#                                                           'highlight': False,
#                                                           'key': 'plus_minus',
#                                                           'label': '+/-',
#                                                           'sortKey': 'plus_minus',
#                                                           'sortable': True,
#                                                           'title': 'Plus/Minus'}},
#                             'points': {'properties': {'align': 'center',
#                                                       'class': '',
#                                                       'hidden': False,
#                                                       'highlight': True,
#                                                       'key': 'points',
#                                                       'label': 'PTS',
#                                                       'sortKey': 'points',
#                                                       'sortable': True,
#                                                       'title': 'Points'}},
#                             'points_per_game': {'properties': {'align': 'center',
#                                                                'class': '',
#                                                                'hidden': False,
#                                                                'highlight': False,
#                                                                'key': 'points_per_game',
#                                                                'label': 'Pt/G',
#                                                                'sortKey': 'ptspg',
#                                                                'sortable': True,
#                                                                'title': 'Points '
#                                                                         'per '
#                                                                         'Game'}},
#                             'position': {'properties': {'align': 'center',
#                                                         'class': '',
#                                                         'hidden': False,
#                                                         'highlight': False,
#                                                         'key': 'position',
#                                                         'label': 'Pos',
#                                                         'sortKey': '',
#                                                         'sortable': True,
#                                                         'title': 'Position'}},
#                             'power_play_assists': {'properties': {'align': 'center',
#                                                                   'class': '',
#                                                                   'hidden': False,
#                                                                   'highlight': False,
#                                                                   'key': 'power_play_assists',
#                                                                   'label': 'PPA',
#                                                                   'sortKey': 'ppassists',
#                                                                   'sortable': True,
#                                                                   'title': 'Power '
#                                                                            'Play '
#                                                                            'Assists'}},
#                             'power_play_goals': {'properties': {'align': 'center',
#                                                                 'class': '',
#                                                                 'hidden': False,
#                                                                 'highlight': False,
#                                                                 'key': 'power_play_goals',
#                                                                 'label': 'PPG',
#                                                                 'sortKey': 'ppgoals',
#                                                                 'sortable': True,
#                                                                 'title': 'Power '
#                                                                          'Play '
#                                                                          'Goals'}},
#                             'rank': {'properties': {'align': 'center',
#                                                     'class': '',
#                                                     'hidden': False,
#                                                     'highlight': False,
#                                                     'key': 'rank',
#                                                     'label': ' ',
#                                                     'sortKey': '',
#                                                     'sortable': True,
#                                                     'title': 'Rank'}},
#                             'rookie': {'properties': {'align': 'center',
#                                                       'class': '',
#                                                       'hidden': False,
#                                                       'highlight': False,
#                                                       'key': 'rookie',
#                                                       'label': '',
#                                                       'sortKey': '',
#                                                       'sortable': True,
#                                                       'title': 'Rookie'}},
#                             'shooting_percentage': {'properties': {'align': 'center',
#                                                                    'class': '',
#                                                                    'hidden': False,
#                                                                    'highlight': False,
#                                                                    'key': 'shooting_percentage',
#                                                                    'label': 'SH%',
#                                                                    'sortKey': 'shooting_percentage',
#                                                                    'sortable': True,
#                                                                    'title': 'Shooting '
#                                                                             'Percentage'}},
#                             'short_handed_assists': {'properties': {'align': 'center',
#                                                                     'class': '',
#                                                                     'hidden': False,
#                                                                     'highlight': False,
#                                                                     'key': 'short_handed_assists',
#                                                                     'label': 'SHA',
#                                                                     'sortKey': 'shassists',
#                                                                     'sortable': True,
#                                                                     'title': 'Short '
#                                                                              'Handed '
#                                                                              'Assists'}},
#                             'short_handed_goals': {'properties': {'align': 'center',
#                                                                   'class': '',
#                                                                   'hidden': False,
#                                                                   'highlight': False,
#                                                                   'key': 'short_handed_goals',
#                                                                   'label': 'SHG',
#                                                                   'sortKey': 'shgoals',
#                                                                   'sortable': True,
#                                                                   'title': 'Short '
#                                                                            'Handed '
#                                                                            'Goals'}},
#                             'shots': {'properties': {'align': 'center',
#                                                      'class': '',
#                                                      'hidden': False,
#                                                      'highlight': False,
#                                                      'key': 'shots',
#                                                      'label': 'SH',
#                                                      'sortKey': 'shots',
#                                                      'sortable': True,
#                                                      'title': 'Shots'}},
#                             'shots_blocked_by_player': {'properties': {'align': 'center',
#                                                                        'class': '',
#                                                                        'hidden': False,
#                                                                        'highlight': False,
#                                                                        'key': 'shots_blocked_by_player',
#                                                                        'label': 'BLK',
#                                                                        'sortKey': '',
#                                                                        'sortable': True,
#                                                                        'title': 'Blocked '
#                                                                                 'shots'}},
#                             'team_code': {'properties': {'align': 'left',
#                                                          'class': '',
#                                                          'hidden': False,
#                                                          'highlight': False,
#                                                          'key': 'team_code',
#                                                          'label': 'Team',
#                                                          'sortKey': '',
#                                                          'sortable': True,
#                                                          'title': 'Name'}}},
#                 'title': ''}]}]

# %%
# nested structure will require appropriate flattening
structure_to_flatten = api_data[0]['sections'][0]['data']

# %%
# The data we want lives in 'prop' and 'row', so we have to unpack it with a for loop: 
rows = [player['row'] for player in structure_to_flatten]
api_df = pd.DataFrame(rows)
api_df.head()
# Out:
#   player_id                     name active position rookie team_code  \
# 0        20  Kendall Coyne Schofield      1        F      0       MIN
# 1       189      Britta Curl-Salemme      1        F      0       MIN
# 2        21             Taylor Heise      1        F      0       MIN
# 3        23             Kelly Pannek      1        F      0       MIN
# 4        58           Brianne Jenner      1        F      0       OTT
#
#   games_played goals shots hits shots_blocked_by_player  \
# 0           15    10    48    5                       5
# 1           15     7    28   17                      17
# 2           15     3    38   13                       3
# 3           15     8    33    2                      15
# 4           16     8    47   12                       5
#
#   ice_time_minutes_seconds shooting_percentage assists points points_per_game  \
# 0                   250:40                20.8       6     16            1.07
# 1                   266:50                25.0       9     16            1.07
# 2                   255:51                 7.9      13     16            1.07
# 3                   256:52                24.2       7     15            1.00
# 4                   305:29                17.0       7     15            0.94
#
#   plus_minus penalty_minutes penalty_minutes_per_game ice_time_per_game_avg  \
# 0         13               0                     0.00                 16:42
# 1         12               8                     0.53                 17:47
# 2         11               6                     0.40                 17:03
# 3         10               2                     0.13                 17:07
# 4          2               6                     0.38                 19:05
#
#   hits_per_game_avg power_play_goals power_play_assists short_handed_goals  \
# 0              0.33                0                  1                  0
# 1              1.13                0                  1                  0
# 2              0.87                0                  2                  0
# 3              0.13                3                  1                  0
# 4              0.75                3                  2                  1
#
#   short_handed_assists faceoff_attempts faceoff_wins faceoff_pct  rank
# 0                    0                1            1       100.0     1
# 1                    0               37           19        51.4     2
# 2                    0              220          106        48.2     3
# 3                    0              271          157        57.9     4
# 4                    0              280          159        56.8     5

# %% [markdown]
# ### Document the origin of the external data and why it was chosen
# Please see the Technique subsection of the Introduction above.

# %% [markdown]
# ## Part 2 - Transformation

# %% [markdown]
# ### Clean and format the external data:
# #### Handle missing values appropriately

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_id                 174 non-null    object
#  1   name                      174 non-null    object
#  2   active                    174 non-null    object
#  3   position                  174 non-null    object
#  4   rookie                    174 non-null    object
#  5   team_code                 174 non-null    object
#  6   games_played              174 non-null    object
#  7   goals                     174 non-null    object
#  8   shots                     174 non-null    object
#  9   hits                      174 non-null    object
#  10  shots_blocked_by_player   174 non-null    object
#  11  ice_time_minutes_seconds  174 non-null    object
#  12  shooting_percentage       174 non-null    object
#  13  assists                   174 non-null    object
#  14  points                    174 non-null    object
#  15  points_per_game           174 non-null    object
#  16  plus_minus                174 non-null    object
#  17  penalty_minutes           174 non-null    object
#  18  penalty_minutes_per_game  174 non-null    object
#  19  ice_time_per_game_avg     174 non-null    object
#  20  hits_per_game_avg         174 non-null    object
#  21  power_play_goals          174 non-null    object
#  22  power_play_assists        174 non-null    object
#  23  short_handed_goals        174 non-null    object
#  24  short_handed_assists      174 non-null    object
#  25  faceoff_attempts          174 non-null    object
#  26  faceoff_wins              174 non-null    object
#  27  faceoff_pct               174 non-null    object
#  28  rank                      174 non-null    int64
# dtypes: int64(1), object(28)
# memory usage: 39.6+ KB

# %% [markdown]
# The imported has no missing values as all entries are `non-null`.
# #### Fix inconsistent field names or types

# %%
# Converting the different columns' types

str_cols = ['name', 'position', 'team_code', 'ice_time_minutes_seconds', 'ice_time_per_game_avg']

int_cols = [
    'player_id', 'rank', 'active', 'rookie', 'games_played', 'goals', 
    'shots', 'hits', 'shots_blocked_by_player', 'assists', 'points', 
    'plus_minus', 'penalty_minutes', 'power_play_goals', 
    'power_play_assists', 'short_handed_goals', 'short_handed_assists', 
    'faceoff_attempts', 'faceoff_wins'
]

float_cols = [
    'shooting_percentage', 'points_per_game', 'penalty_minutes_per_game', 
    'hits_per_game_avg', 'faceoff_pct' ]

for col in str_cols:
    api_df[col] =  api_df[col].astype("string")

for col in int_cols:
    api_df[col] =  api_df[col].astype("int64")

for col in float_cols:
    api_df[col] =  api_df[col].astype("float64")

api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_id                 174 non-null    int64
#  1   name                      174 non-null    string
#  2   active                    174 non-null    int64
#  3   position                  174 non-null    string
#  4   rookie                    174 non-null    int64
#  5   team_code                 174 non-null    string
#  6   games_played              174 non-null    int64
#  7   goals                     174 non-null    int64
#  8   shots                     174 non-null    int64
#  9   hits                      174 non-null    int64
#  10  shots_blocked_by_player   174 non-null    int64
#  11  ice_time_minutes_seconds  174 non-null    string
#  12  shooting_percentage       174 non-null    float64
#  13  assists                   174 non-null    int64
#  14  points                    174 non-null    int64
#  15  points_per_game           174 non-null    float64
#  16  plus_minus                174 non-null    int64
#  17  penalty_minutes           174 non-null    int64
#  18  penalty_minutes_per_game  174 non-null    float64
#  19  ice_time_per_game_avg     174 non-null    string
#  20  hits_per_game_avg         174 non-null    float64
#  21  power_play_goals          174 non-null    int64
#  22  power_play_assists        174 non-null    int64
#  23  short_handed_goals        174 non-null    int64
#  24  short_handed_assists      174 non-null    int64
#  25  faceoff_attempts          174 non-null    int64
#  26  faceoff_wins              174 non-null    int64
#  27  faceoff_pct               174 non-null    float64
#  28  rank                      174 non-null    int64
# dtypes: float64(5), int64(19), string(5)
# memory usage: 39.6 KB

# %%
api_df.head()
# Out:
#    player_id                     name  active position  rookie team_code  \
# 0         20  Kendall Coyne Schofield       1        F       0       MIN
# 1        189      Britta Curl-Salemme       1        F       0       MIN
# 2         21             Taylor Heise       1        F       0       MIN
# 3         23             Kelly Pannek       1        F       0       MIN
# 4         58           Brianne Jenner       1        F       0       OTT
#
#    games_played  goals  shots  hits  shots_blocked_by_player  \
# 0            15     10     48     5                        5
# 1            15      7     28    17                       17
# 2            15      3     38    13                        3
# 3            15      8     33     2                       15
# 4            16      8     47    12                        5
#
#   ice_time_minutes_seconds  shooting_percentage  assists  points  \
# 0                   250:40                 20.8        6      16
# 1                   266:50                 25.0        9      16
# 2                   255:51                  7.9       13      16
# 3                   256:52                 24.2        7      15
# 4                   305:29                 17.0        7      15
#
#    points_per_game  plus_minus  penalty_minutes  penalty_minutes_per_game  \
# 0             1.07          13                0                      0.00
# 1             1.07          12                8                      0.53
# 2             1.07          11                6                      0.40
# 3             1.00          10                2                      0.13
# 4             0.94           2                6                      0.38
#
#   ice_time_per_game_avg  hits_per_game_avg  power_play_goals  \
# 0                 16:42               0.33                 0
# 1                 17:47               1.13                 0
# 2                 17:03               0.87                 0
# 3                 17:07               0.13                 3
# 4                 19:05               0.75                 3
#
#    power_play_assists  short_handed_goals  short_handed_assists  \
# 0                   1                   0                     0
# 1                   1                   0                     0
# 2                   2                   0                     0
# 3                   1                   0                     0
# 4                   2                   1                     0
#
#    faceoff_attempts  faceoff_wins  faceoff_pct  rank
# 0                 1             1        100.0     1
# 1                37            19         51.4     2
# 2               220           106         48.2     3
# 3               271           157         57.9     4
# 4               280           159         56.8     5

# %%
# Rename some of the columns to ensure that they match with with values they represent and also for merging purposes

api_df = api_df.rename(columns={
    "name" : "player_name",
    "player_id" : "player_key"
})

# %% [markdown]
# #### Drop irrelevant columns
# These details are all summary statistics by players. We will only be keeping a few for comparing against shot stats within a single game. Mostly, we are utilizing theis data for practice in merging datasets.

# %%
api_df
# Out:
#      player_key                player_name  active position  rookie team_code  \
# 0            20    Kendall Coyne Schofield       1        F       0       MIN
# 1           189        Britta Curl-Salemme       1        F       0       MIN
# 2            21               Taylor Heise       1        F       0       MIN
# 3            23               Kelly Pannek       1        F       0       MIN
# 4            58             Brianne Jenner       1        F       0       OTT
# ..          ...                        ...     ...      ...     ...       ...
# 169         269              Vanessa Upson       1        F       1       MIN
# 170         217               Taylor House       1        F       0       OTT
# 171         129  Mellissa Channell-Watkins       1        D       0       VAN
# 172         118                 Emma Greco       1        D       0       OTT
# 173         101                Alexa Vasko       1        F       0       OTT
#
#      games_played  goals  shots  hits  shots_blocked_by_player  \
# 0              15     10     48     5                        5
# 1              15      7     28    17                       17
# 2              15      3     38    13                        3
# 3              15      8     33     2                       15
# 4              16      8     47    12                        5
# ..            ...    ...    ...   ...                      ...
# 169            13      0      6     0                        5
# 170            15      0      5    14                        5
# 171            16      0     12    29                       19
# 172            16      0      4     8                        5
# 173            16      0     11    28                       11
#
#     ice_time_minutes_seconds  shooting_percentage  assists  points  \
# 0                     250:40                 20.8        6      16
# 1                     266:50                 25.0        9      16
# 2                     255:51                  7.9       13      16
# 3                     256:52                 24.2        7      15
# 4                     305:29                 17.0        7      15
# ..                       ...                  ...      ...     ...
# 169                    68:54                  0.0        0       0
# 170                    94:34                  0.0        0       0
# 171                   305:19                  0.0        0       0
# 172                    34:28                  0.0        0       0
# 173                   168:11                  0.0        0       0
#
#      points_per_game  plus_minus  penalty_minutes  penalty_minutes_per_game  \
# 0               1.07          13                0                      0.00
# 1               1.07          12                8                      0.53
# 2               1.07          11                6                      0.40
# 3               1.00          10                2                      0.13
# 4               0.94           2                6                      0.38
# ..               ...         ...              ...                       ...
# 169             0.00          -2                0                      0.00
# 170             0.00          -3                0                      0.00
# 171             0.00          -6                2                      0.13
# 172             0.00          -2               23                      1.44
# 173             0.00          -3                2                      0.13
#
#     ice_time_per_game_avg  hits_per_game_avg  power_play_goals  \
# 0                   16:42               0.33                 0
# 1                   17:47               1.13                 0
# 2                   17:03               0.87                 0
# 3                   17:07               0.13                 3
# 4                   19:05               0.75                 3
# ..                    ...                ...               ...
# 169                  5:18               0.00                 0
# 170                  6:18               0.93                 0
# 171                 19:04               1.81                 0
# 172                  6:38               0.50                 0
# 173                 10:30               1.75                 0
#
#      power_play_assists  short_handed_goals  short_handed_assists  \
# 0                     1                   0                     0
# 1                     1                   0                     0
# 2                     2                   0                     0
# 3                     1                   0                     0
# 4                     2                   1                     0
# ..                  ...                 ...                   ...
# 169                   0                   0                     0
# 170                   0                   0                     0
# 171                   0                   0                     0
# 172                   0                   0                     0
# 173                   0                   0                     0
#
#      faceoff_attempts  faceoff_wins  faceoff_pct  rank
# 0                   1             1        100.0     1
# 1                  37            19         51.4     2
# 2                 220           106         48.2     3
# 3                 271           157         57.9     4
# 4                 280           159         56.8     5
# ..                ...           ...          ...   ...
# 169                36            14         38.9   170
# 170                13             5         38.5   171
# 171                 0             0          0.0   172
# 172                 0             0          0.0   173
# 173               125            73         58.4   174
#
# [174 rows x 29 columns]

# %%
api_df = api_df.drop(['player_name','active','position','team_code'], axis=1)

# %% [markdown]
# ### Merge or join with your original dataset if relevant

# %% [markdown]
# #### Merge two dataframes as an inner join

# %%
combined_df = pd.merge(df, api_df, on='player_key', how='left')

combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   shooting_team             15 non-null     string
#  1   game_date                 15 non-null     datetime64[ns]
#  2   duration                  15 non-null     datetime64[ns]
#  3   shooter_name              15 non-null     string
#  4   player_key                15 non-null     int64
#  5   position                  15 non-null     string
#  6   shoots_handed             15 non-null     string
#  7   hometown                  15 non-null     string
#  8   birthdate                 15 non-null     datetime64[ns]
#  9   jersey_number             15 non-null     int64
#  10  shot_key                  15 non-null     int64
#  11  shot_type                 15 non-null     string
#  12  shot_time                 15 non-null     datetime64[ns]
#  13  shot_quality              15 non-null     string
#  14  goalie_name               15 non-null     string
#  15  is_goal                   15 non-null     int64
#  16  blocker_name              15 non-null     string
#  17  assist1_name              15 non-null     string
#  18  assist2_name              15 non-null     string
#  19  is_power_play_goal        15 non-null     int64
#  20  is_short_handed_goal      15 non-null     int64
#  21  is_empty_net_goal         15 non-null     int64
#  22  is_penalty_shot_goal      15 non-null     int64
#  23  is_insurance_goal         15 non-null     int64
#  24  is_game_winning_goal      15 non-null     int64
#  25  x_location                15 non-null     int64
#  26  y_location                15 non-null     int64
#  27  home_state_or_territory   15 non-null     string
#  28  duration_hours            15 non-null     float64
#  29  rookie                    15 non-null     int64
#  30  games_played              15 non-null     int64
#  31  goals                     15 non-null     int64
#  32  shots                     15 non-null     int64
#  33  hits                      15 non-null     int64
#  34  shots_blocked_by_player   15 non-null     int64
#  35  ice_time_minutes_seconds  15 non-null     string
#  36  shooting_percentage       15 non-null     float64
#  37  assists                   15 non-null     int64
#  38  points                    15 non-null     int64
#  39  points_per_game           15 non-null     float64
#  40  plus_minus                15 non-null     int64
#  41  penalty_minutes           15 non-null     int64
#  42  penalty_minutes_per_game  15 non-null     float64
#  43  ice_time_per_game_avg     15 non-null     string
#  44  hits_per_game_avg         15 non-null     float64
#  45  power_play_goals          15 non-null     int64
#  46  power_play_assists        15 non-null     int64
#  47  short_handed_goals        15 non-null     int64
#  48  short_handed_assists      15 non-null     int64
#  49  faceoff_attempts          15 non-null     int64
#  50  faceoff_wins              15 non-null     int64
#  51  faceoff_pct               15 non-null     float64
#  52  rank                      15 non-null     int64
# dtypes: datetime64[ns](4), float64(6), int64(29), string(14)
# memory usage: 6.3 KB

# %% [markdown]
# ### Create at least one derived column (e.g., combining fields, date extraction, totals)

# %%
#year of birth
combined_df['year_of_birth'] = combined_df['birthdate'].dt.year

# %% [markdown]
# ### Ensure the final DataFrame is consistent and usable for analysis
# Our dataframe was originally scoped to the shot level in an individual game. With this joined summary data we could possibly summarize fields from the original at a lower level than the season summary data and compare.

# %% [markdown]
# ## Part 3 - Load

# %% [markdown]
# ### Export the final transformed dataset to a CSV

# %%
combined_df.to_csv('week7_final_data.csv')

# %% [markdown]
# ### Save all intermediate and merged versions for backup

# %%
combined_df.to_sql('week7table', conn, if_exists='replace', index=False)
conn.commit()
conn.close()

# %% [markdown]
# ##  Part 4 – Documentation & Reflection

# %% [markdown]
# #### Write-up
# Please see included file here: [pwhl-database-Week7_ReadMe.txt](https://github.com/alyzukas/pwhl-database/wiki)
